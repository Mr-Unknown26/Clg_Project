# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from faker import Faker
from random import randint

# %%
dj= pd.read_csv("C:\\Users\\Afzan Shaikh\\OneDrive\\Desktop\\MiniPr.csv")

# %%
dj['Price'] = [randint(10000, 100000) for _ in range(len(dj))]

# %%
print("First 5 rows")
dj.head()
# Out:
# First 5 rows
#            Name  Age                     Email       City     Product  \
# 0    Ravi Kumar   26    ravi.kumar@example.com     Mumbai  Smartphone
# 1  Aditi Sharma   32  aditi.sharma@example.com      Delhi      Laptop
# 2   Aryan Gupta   45   aryan.gupta@example.com  Bangalore      Tablet
# 3    Isha Patel   29    isha.patel@example.com       Pune  Smartwatch
# 4  Nikhil Singh   38  nikhil.singh@example.com    Chennai  Headphones
#
#                                               Review  Rating  Price
# 0  The smartphone is very user-friendly and durable.       8  94305
# 1  This laptop has a great performance and batter...       9  56425
# 2    The tablet is lightweight and ideal for travel.       7  59622
# 3  The smartwatch offers excellent fitness tracking.       8  67028
# 4          The headphones have superb sound quality.       9  33271

# %%
print("\n Last 5 rows")
dj.tail()
# Out:
#  Last 5 rows
#            Name  Age                     Email       City         Product  \
# 5   Pooja Verma   24   pooja.verma@example.com      Surat          Camera
# 6   Aarav Mehta   40   aarav.mehta@example.com  Ahmedabad              TV
# 7    Reena Shah   31    reena.shah@example.com     Jaipur         Speaker
# 8  Aditya Joshi   27  aditya.joshi@example.com    Kolkata  Gaming Console
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad          Router
#
#                                               Review  Rating  Price
# 5    The camera captures beautiful and clear photos.       8  43426
# 6  The TV has a stunning display and vibrant colors.      10  22839
# 7  The speaker is portable and delivers powerful ...       7  52369
# 8  The gaming console is fast and has a great gam...      10  24608
# 9  The router provides excellent internet speed a...       9  90812

# %%
print("Shape of Dataset:",dj.shape)
# Out:
# Shape of Dataset: (10, 6)

# %%
print(dj.dtypes)
# Out:
# Name       object
# Age         int64
# Email      object
# Product    object
# Review     object
# Rating      int64
# dtype: object

# %%
print("Missing values in each column:")
dj.isnull().sum()
# Out:
# Missing values in each column:
# Name       0
# Age        0
# Email      0
# Product    0
# Review     0
# Rating     0
# dtype: int64

# %%
print("Summary statistics for numerical columns:")
dj.describe()
# Out:
# Summary statistics for numerical columns:
#              Age     Rating
# count  10.000000  10.000000
# mean   32.800000   8.500000
# std     6.779053   1.080123
# min    24.000000   7.000000
# 25%    27.500000   8.000000
# 50%    31.500000   8.500000
# 75%    37.500000   9.000000
# max    45.000000  10.000000

# %%
dj.duplicated().sum()
print("Duplicate Rows in dataset :")
# Out:
# Duplicate Rows in dataset :

# %%
dj.drop_duplicates()
print("Remove Duplicate Rows :")
# Out:
# Remove Duplicate Rows :

# %%
print("The unique Num is :")
dj.nunique()
# Out:
# The unique Num is :
# Name       10
# Age        10
# Email      10
# Product    10
# Review     10
# Rating      4
# dtype: int64

# %%
dj['Review'].replace('NA', np.nan)
# Out:
# 0    The smartphone is very user-friendly and durable.
# 1    This laptop has a great performance and batter...
# 2      The tablet is lightweight and ideal for travel.
# 3    The smartwatch offers excellent fitness tracking.
# 4            The headphones have superb sound quality.
# 5      The camera captures beautiful and clear photos.
# 6    The TV has a stunning display and vibrant colors.
# 7    The speaker is portable and delivers powerful ...
# 8    The gaming console is fast and has a great gam...
# 9    The router provides excellent internet speed a...
# Name: Review, dtype: object

# %%
print("Drop missing values:")
dj.dropna()
# Out:
# Drop missing values:
#            Name  Age                     Email       City         Product  \
# 0    Ravi Kumar   26    ravi.kumar@example.com     Mumbai      Smartphone
# 1  Aditi Sharma   32  aditi.sharma@example.com      Delhi          Laptop
# 2   Aryan Gupta   45   aryan.gupta@example.com  Bangalore          Tablet
# 3    Isha Patel   29    isha.patel@example.com       Pune      Smartwatch
# 4  Nikhil Singh   38  nikhil.singh@example.com    Chennai      Headphones
# 5   Pooja Verma   24   pooja.verma@example.com      Surat          Camera
# 6   Aarav Mehta   40   aarav.mehta@example.com  Ahmedabad              TV
# 7    Reena Shah   31    reena.shah@example.com     Jaipur         Speaker
# 8  Aditya Joshi   27  aditya.joshi@example.com    Kolkata  Gaming Console
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad          Router
#
#                                               Review  Rating  Price
# ...

# %%
print("Drop the columns :")
dj.drop(columns=['Email'])
# Out:
# Drop the columns :
#            Name  Age       City         Product  \
# 0    Ravi Kumar   26     Mumbai      Smartphone
# 1  Aditi Sharma   32      Delhi          Laptop
# 2   Aryan Gupta   45  Bangalore          Tablet
# 3    Isha Patel   29       Pune      Smartwatch
# 4  Nikhil Singh   38    Chennai      Headphones
# 5   Pooja Verma   24      Surat          Camera
# 6   Aarav Mehta   40  Ahmedabad              TV
# 7    Reena Shah   31     Jaipur         Speaker
# 8  Aditya Joshi   27    Kolkata  Gaming Console
# 9   Suman Reddy   36  Hyderabad          Router
#
#                                               Review  Rating  Price
# 0  The smartphone is very user-friendly and durable.       8  31371
# 1  This laptop has a great performance and batter...       9  70750
# 2    The tablet is lightweight and ideal for travel.       7  23791
# 3  The smartwatch offers excellent fitness tracking.       8  69326
# 4          The headphones have superb sound quality.       9  41242
# ...

# %%
dj.rename(columns={'Product Review': 'Review'})
# Out:
#            Name  Age                     Email       City         Product  \
# 0    Ravi Kumar   26    ravi.kumar@example.com     Mumbai      Smartphone
# 1  Aditi Sharma   32  aditi.sharma@example.com      Delhi          Laptop
# 2   Aryan Gupta   45   aryan.gupta@example.com  Bangalore          Tablet
# 3    Isha Patel   29    isha.patel@example.com       Pune      Smartwatch
# 4  Nikhil Singh   38  nikhil.singh@example.com    Chennai      Headphones
# 5   Pooja Verma   24   pooja.verma@example.com      Surat          Camera
# 6   Aarav Mehta   40   aarav.mehta@example.com  Ahmedabad              TV
# 7    Reena Shah   31    reena.shah@example.com     Jaipur         Speaker
# 8  Aditya Joshi   27  aditya.joshi@example.com    Kolkata  Gaming Console
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad          Router
#
#                                               Review  Rating  Price
# 0  The smartphone is very user-friendly and durable.       8  31371
# ...

# %%
dj['Date'] = '2025-03-04'
dj['Date'] = pd.to_datetime(dj['Date'], format='%Y-%m-%d')
dj
# Out:
#            Name  Age                     Email       City         Product  \
# 0    Ravi Kumar   26    ravi.kumar@example.com     Mumbai      Smartphone
# 1  Aditi Sharma   32  aditi.sharma@example.com      Delhi          Laptop
# 2   Aryan Gupta   45   aryan.gupta@example.com  Bangalore          Tablet
# 3    Isha Patel   29    isha.patel@example.com       Pune      Smartwatch
# 4  Nikhil Singh   38  nikhil.singh@example.com    Chennai      Headphones
# 5   Pooja Verma   24   pooja.verma@example.com      Surat          Camera
# 6   Aarav Mehta   40   aarav.mehta@example.com  Ahmedabad              TV
# 7    Reena Shah   31    reena.shah@example.com     Jaipur         Speaker
# 8  Aditya Joshi   27  aditya.joshi@example.com    Kolkata  Gaming Console
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad          Router
#
#                                               Review  Rating  Price       Date
# ...

# %%
age_column= dj['Age']
print("Age Column:")
print(age_column)
# Out:
# Age Column:
# 0    26
# 1    32
# 2    45
# 3    29
# 4    38
# 5    24
# 6    40
# 7    31
# 8    27
# 9    36
# Name: Age, dtype: int64

# %%
name_city_columns = dj[['Name', 'City']]
print(name_city_columns)
# Out:
#            Name       City
# 0    Ravi Kumar     Mumbai
# 1  Aditi Sharma      Delhi
# 2   Aryan Gupta  Bangalore
# 3    Isha Patel       Pune
# 4  Nikhil Singh    Chennai
# 5   Pooja Verma      Surat
# 6   Aarav Mehta  Ahmedabad
# 7    Reena Shah     Jaipur
# 8  Aditya Joshi    Kolkata
# 9   Suman Reddy  Hyderabad

# %%
dj[dj['Age']>30]
# Out:
#            Name  Age                     Email       City     Product  \
# 1  Aditi Sharma   32  aditi.sharma@example.com      Delhi      Laptop
# 2   Aryan Gupta   45   aryan.gupta@example.com  Bangalore      Tablet
# 4  Nikhil Singh   38  nikhil.singh@example.com    Chennai  Headphones
# 6   Aarav Mehta   40   aarav.mehta@example.com  Ahmedabad          TV
# 7    Reena Shah   31    reena.shah@example.com     Jaipur     Speaker
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad      Router
#
#                                               Review  Rating  Price       Date
# 1  This laptop has a great performance and batter...       9  70750 2025-03-04
# 2    The tablet is lightweight and ideal for travel.       7  23791 2025-03-04
# 4          The headphones have superb sound quality.       9  41242 2025-03-04
# 6  The TV has a stunning display and vibrant colors.      10  14712 2025-03-04
# 7  The speaker is portable and delivers powerful ...       7  24929 2025-03-04
# ...

# %%
dj[dj['City']=='Mumbai']
# Out:
#          Name  Age                   Email    City     Product  \
# 0  Ravi Kumar   26  ravi.kumar@example.com  Mumbai  Smartphone
#
#                                               Review  Rating
# 0  The smartphone is very user-friendly and durable.       8

# %%
dj.sort_values(by='Age')
# Out:
#            Name  Age                     Email       City         Product  \
# 5   Pooja Verma   24   pooja.verma@example.com      Surat          Camera
# 0    Ravi Kumar   26    ravi.kumar@example.com     Mumbai      Smartphone
# 8  Aditya Joshi   27  aditya.joshi@example.com    Kolkata  Gaming Console
# 3    Isha Patel   29    isha.patel@example.com       Pune      Smartwatch
# 7    Reena Shah   31    reena.shah@example.com     Jaipur         Speaker
# 1  Aditi Sharma   32  aditi.sharma@example.com      Delhi          Laptop
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad          Router
# 4  Nikhil Singh   38  nikhil.singh@example.com    Chennai      Headphones
# 6   Aarav Mehta   40   aarav.mehta@example.com  Ahmedabad              TV
# 2   Aryan Gupta   45   aryan.gupta@example.com  Bangalore          Tablet
#
#                                               Review  Rating  Price
# 5    The camera captures beautiful and clear photos.       8  81727
# ...

# %%
dj.sort_values(by='City')
# Out:
#            Name  Age                     Email       City         Product  \
# 6   Aarav Mehta   40   aarav.mehta@example.com  Ahmedabad              TV
# 2   Aryan Gupta   45   aryan.gupta@example.com  Bangalore          Tablet
# 4  Nikhil Singh   38  nikhil.singh@example.com    Chennai      Headphones
# 1  Aditi Sharma   32  aditi.sharma@example.com      Delhi          Laptop
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad          Router
# 7    Reena Shah   31    reena.shah@example.com     Jaipur         Speaker
# 8  Aditya Joshi   27  aditya.joshi@example.com    Kolkata  Gaming Console
# 0    Ravi Kumar   26    ravi.kumar@example.com     Mumbai      Smartphone
# 3    Isha Patel   29    isha.patel@example.com       Pune      Smartwatch
# 5   Pooja Verma   24   pooja.verma@example.com      Surat          Camera
#
#                                               Review  Rating  Price
# 6  The TV has a stunning display and vibrant colors.      10  67736
# ...

# %%
dj.sort_values(by='Price',ascending=False)
# Out:
#            Name  Age                     Email       City         Product  \
# 4  Nikhil Singh   38  nikhil.singh@example.com    Chennai      Headphones
# 5   Pooja Verma   24   pooja.verma@example.com      Surat          Camera
# 2   Aryan Gupta   45   aryan.gupta@example.com  Bangalore          Tablet
# 6   Aarav Mehta   40   aarav.mehta@example.com  Ahmedabad              TV
# 1  Aditi Sharma   32  aditi.sharma@example.com      Delhi          Laptop
# 7    Reena Shah   31    reena.shah@example.com     Jaipur         Speaker
# 0    Ravi Kumar   26    ravi.kumar@example.com     Mumbai      Smartphone
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad          Router
# 8  Aditya Joshi   27  aditya.joshi@example.com    Kolkata  Gaming Console
# 3    Isha Patel   29    isha.patel@example.com       Pune      Smartwatch
#
#                                               Review  Rating  Price
# 4          The headphones have superb sound quality.       9  94883
# ...

# %%
print('Sort City and Age :')
dj.sort_values(by=['City','Age'])
# Out:
# Sort City and Age :
#            Name  Age                     Email       City         Product  \
# 6   Aarav Mehta   40   aarav.mehta@example.com  Ahmedabad              TV
# 2   Aryan Gupta   45   aryan.gupta@example.com  Bangalore          Tablet
# 4  Nikhil Singh   38  nikhil.singh@example.com    Chennai      Headphones
# 1  Aditi Sharma   32  aditi.sharma@example.com      Delhi          Laptop
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad          Router
# 7    Reena Shah   31    reena.shah@example.com     Jaipur         Speaker
# 8  Aditya Joshi   27  aditya.joshi@example.com    Kolkata  Gaming Console
# 0    Ravi Kumar   26    ravi.kumar@example.com     Mumbai      Smartphone
# 3    Isha Patel   29    isha.patel@example.com       Pune      Smartwatch
# 5   Pooja Verma   24   pooja.verma@example.com      Surat          Camera
#
#                                               Review  Rating  Price
# ...

# %%
print('First 3 Rows of Age:')
dj.sort_values(by='Age').head(3)
# Out:
# First 3 Rows of Age
#            Name  Age                     Email     City         Product  \
# 5   Pooja Verma   24   pooja.verma@example.com    Surat          Camera
# 0    Ravi Kumar   26    ravi.kumar@example.com   Mumbai      Smartphone
# 8  Aditya Joshi   27  aditya.joshi@example.com  Kolkata  Gaming Console
#
#                                               Review  Rating  Price
# 5    The camera captures beautiful and clear photos.       8  81727
# 0  The smartphone is very user-friendly and durable.       8  38783
# 8  The gaming console is fast and has a great gam...      10  34756

# %%
dj.rename(columns={'City':'Location'})
# Out:
#            Name  Age                     Email   Location         Product  \
# 0    Ravi Kumar   26    ravi.kumar@example.com     Mumbai      Smartphone
# 1  Aditi Sharma   32  aditi.sharma@example.com      Delhi          Laptop
# 2   Aryan Gupta   45   aryan.gupta@example.com  Bangalore          Tablet
# 3    Isha Patel   29    isha.patel@example.com       Pune      Smartwatch
# 4  Nikhil Singh   38  nikhil.singh@example.com    Chennai      Headphones
# 5   Pooja Verma   24   pooja.verma@example.com      Surat          Camera
# 6   Aarav Mehta   40   aarav.mehta@example.com  Ahmedabad              TV
# 7    Reena Shah   31    reena.shah@example.com     Jaipur         Speaker
# 8  Aditya Joshi   27  aditya.joshi@example.com    Kolkata  Gaming Console
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad          Router
#
#                                               Review  Rating  Price
# 0  The smartphone is very user-friendly and durable.       8  38783
# ...

# %%
dj.rename(columns={'Age':'Person_Age'})
# Out:
#            Name  Person_Age                     Email       City  \
# 0    Ravi Kumar          26    ravi.kumar@example.com     Mumbai
# 1  Aditi Sharma          32  aditi.sharma@example.com      Delhi
# 2   Aryan Gupta          45   aryan.gupta@example.com  Bangalore
# 3    Isha Patel          29    isha.patel@example.com       Pune
# 4  Nikhil Singh          38  nikhil.singh@example.com    Chennai
# 5   Pooja Verma          24   pooja.verma@example.com      Surat
# 6   Aarav Mehta          40   aarav.mehta@example.com  Ahmedabad
# 7    Reena Shah          31    reena.shah@example.com     Jaipur
# 8  Aditya Joshi          27  aditya.joshi@example.com    Kolkata
# 9   Suman Reddy          36   suman.reddy@example.com  Hyderabad
#
#           Product                                             Review  Rating  \
# 0      Smartphone  The smartphone is very user-friendly and durable.       8
# 1          Laptop  This laptop has a great performance and batter...       9
# ...

# %%
dj.rename(columns={'Name':'Person',
                  'Email':'Person_Email'})
# Out:
#          Person  Age              Person_Email       City         Product  \
# 0    Ravi Kumar   26    ravi.kumar@example.com     Mumbai      Smartphone
# 1  Aditi Sharma   32  aditi.sharma@example.com      Delhi          Laptop
# 2   Aryan Gupta   45   aryan.gupta@example.com  Bangalore          Tablet
# 3    Isha Patel   29    isha.patel@example.com       Pune      Smartwatch
# 4  Nikhil Singh   38  nikhil.singh@example.com    Chennai      Headphones
# 5   Pooja Verma   24   pooja.verma@example.com      Surat          Camera
# 6   Aarav Mehta   40   aarav.mehta@example.com  Ahmedabad              TV
# 7    Reena Shah   31    reena.shah@example.com     Jaipur         Speaker
# 8  Aditya Joshi   27  aditya.joshi@example.com    Kolkata  Gaming Console
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad          Router
#
#                                               Review  Rating  Price
# 0  The smartphone is very user-friendly and durable.       8  38783
# ...

# %%
dj.rename(columns={'Person_Email':'Email'})
# Out:
#            Name  Age                     Email       City         Product  \
# 0    Ravi Kumar   26    ravi.kumar@example.com     Mumbai      Smartphone
# 1  Aditi Sharma   32  aditi.sharma@example.com      Delhi          Laptop
# 2   Aryan Gupta   45   aryan.gupta@example.com  Bangalore          Tablet
# 3    Isha Patel   29    isha.patel@example.com       Pune      Smartwatch
# 4  Nikhil Singh   38  nikhil.singh@example.com    Chennai      Headphones
# 5   Pooja Verma   24   pooja.verma@example.com      Surat          Camera
# 6   Aarav Mehta   40   aarav.mehta@example.com  Ahmedabad              TV
# 7    Reena Shah   31    reena.shah@example.com     Jaipur         Speaker
# 8  Aditya Joshi   27  aditya.joshi@example.com    Kolkata  Gaming Console
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad          Router
#
#                                               Review  Rating  Price       Date
# ...

# %%
dj['Age'].mean()
# Out:
# 32.8

# %%
dj['Price'].sum()
# Out:
# 570366

# %%
dj['City'].value_counts()
# Out:
# City
# Mumbai       1
# Delhi        1
# Bangalore    1
# Pune         1
# Chennai      1
# Surat        1
# Ahmedabad    1
# Jaipur       1
# Kolkata      1
# Hyderabad    1
# Name: count, dtype: int64

# %%
dj.groupby('City')['Age'].sum()
# Out:
# City
# Ahmedabad    40
# Bangalore    45
# Chennai      38
# Delhi        32
# Hyderabad    36
# Jaipur       31
# Kolkata      27
# Mumbai       26
# Pune         29
# Surat        24
# Name: Age, dtype: int64

# %%
dj['Age'].max()
# Out:
# 45

# %%
dj['Price'].min()
# Out:
# 14712

# %%
city_age = dj.groupby('City')['Age'].mean().reset_index()
plt.figure(figsize=(10, 6))
plt.bar(city_age['City'], city_age['Age'], color='skyblue')
plt.xlabel('City')
plt.ylabel('Average Age')
plt.title('City vs. Average Age')
plt.xticks(rotation=45)
plt.show()

# %%
plt.plot(dj.index, dj['Age'], marker='o', linestyle='-', color='b')
plt.xlabel('Index')
plt.ylabel('Age')
plt.title('Age over Index')
plt.grid(False)
plt.show()

# %%
plt.hist(dj['Age'], bins=20, color='Orange', edgecolor='red')
plt.title('Histogram')
plt.xlabel('Bins')
plt.ylabel('Frequency')
plt.show()

# %%
City=dj['City'].value_counts()
plt.pie(City, labels=City.index, autopct='%1.2f%%')
plt.title('Pie Chart')
plt.axis('equal') 
plt.show()

# %%
plt.scatter(dj['Age'], dj['Price'], marker='o',c ='blue')
plt.xlabel('Age')
plt.ylabel('Price')
plt.title('Scatter Plot between Age and Price')
plt.grid(False)
plt.show()

# %%
dj['City'].str.lower()
# Out:
# 0       mumbai
# 1        delhi
# 2    bangalore
# 3         pune
# 4      chennai
# 5        surat
# 6    ahmedabad
# 7       jaipur
# 8      kolkata
# 9    hyderabad
# Name: City, dtype: object

# %%
dj['City'].head(3)
# Out:
# 0       Mumbai
# 1        Delhi
# 2    Bangalore
# Name: City, dtype: object

# %%
dj[['First_Name', 'Last_Name']] = dj['Name'].str.split(' ', 1, expand=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dj[['First_Name', 'Last_Name']] = dj['Name'].str.split(' ', 1, expand=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\strings\accessor.py:137, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     132     msg = (
#     133         f"Cannot use .str.{func_name} with values of "
#     134         f"inferred dtype '{self._inferred_dtype}'."
#     135     )
#     136     raise TypeError(msg)
# --> 137 return func(self, *args, **kwargs)
#
# TypeError: StringMethods.split() takes from 1 to 2 positional arguments but 3 positional arguments (and 1 keyword-only argument) were given

# %%
dj['City'] = dj['City'].str.replace(' ', '_')
dj
# Out:
#            Name  Age                     Email       City         Product  \
# 0    Ravi Kumar   26    ravi.kumar@example.com     Mumbai      Smartphone
# 1  Aditi Sharma   32  aditi.sharma@example.com      Delhi          Laptop
# 2   Aryan Gupta   45   aryan.gupta@example.com  Bangalore          Tablet
# 3    Isha Patel   29    isha.patel@example.com       Pune      Smartwatch
# 4  Nikhil Singh   38  nikhil.singh@example.com    Chennai      Headphones
# 5   Pooja Verma   24   pooja.verma@example.com      Surat          Camera
# 6   Aarav Mehta   40   aarav.mehta@example.com  Ahmedabad              TV
# 7    Reena Shah   31    reena.shah@example.com     Jaipur         Speaker
# 8  Aditya Joshi   27  aditya.joshi@example.com    Kolkata  Gaming Console
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad          Router
#
#                                               Review  Rating  Price       Date
# ...

# %%
dj.iloc[0]
# Out:
# Name                                              Ravi Kumar
# Age                                                       26
# Email                                 ravi.kumar@example.com
# City                                                  Mumbai
# Product                                           Smartphone
# Review     The smartphone is very user-friendly and durable.
# Rating                                                     8
# Price                                                  31371
# Date                                     2025-03-04 00:00:00
# Name: 0, dtype: object

# %%
last_three_rows = dj.iloc[-3:]
print(last_three_rows)
# Out:
#            Name  Age                     Email       City         Product  \
# 7    Reena Shah   31    reena.shah@example.com     Jaipur         Speaker
# 8  Aditya Joshi   27  aditya.joshi@example.com    Kolkata  Gaming Console
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad          Router
#
#                                               Review  Rating  Price       Date
# 7  The speaker is portable and delivers powerful ...       7  24929 2025-03-04
# 8  The gaming console is fast and has a great gam...      10  74377 2025-03-04
# 9  The router provides excellent internet speed a...       9  75436 2025-03-04

# %%
First_Five_rows = dj.iloc[:5, :3]
print(First_Five_rows)
# Out:
#            Name  Age                     Email
# 0    Ravi Kumar   26    ravi.kumar@example.com
# 1  Aditi Sharma   32  aditi.sharma@example.com
# 2   Aryan Gupta   45   aryan.gupta@example.com
# 3    Isha Patel   29    isha.patel@example.com
# 4  Nikhil Singh   38  nikhil.singh@example.com

# %%
dj.iloc[:,[1,2]]
# Out:
#    Age                     Email
# 0   26    ravi.kumar@example.com
# 1   32  aditi.sharma@example.com
# 2   45   aryan.gupta@example.com
# 3   29    isha.patel@example.com
# 4   38  nikhil.singh@example.com
# 5   24   pooja.verma@example.com
# 6   40   aarav.mehta@example.com
# 7   31    reena.shah@example.com
# 8   27  aditya.joshi@example.com
# 9   36   suman.reddy@example.com

# %%
dj.iloc[3,1]
# Out:
# 29

# %%
dj.loc[dj['Name'] == 'Aditi Sharma']
# Out:
#            Name  Age                     Email   City Product  \
# 1  Aditi Sharma   32  aditi.sharma@example.com  Delhi  Laptop
#
#                                               Review  Rating  Price
# 1  This laptop has a great performance and batter...       9  56425

# %%
dj.loc[dj['Age'] >30]
# Out:
#            Name  Age                     Email       City     Product  \
# 1  Aditi Sharma   32  aditi.sharma@example.com      Delhi      Laptop
# 2   Aryan Gupta   45   aryan.gupta@example.com  Bangalore      Tablet
# 4  Nikhil Singh   38  nikhil.singh@example.com    Chennai  Headphones
# 6   Aarav Mehta   40   aarav.mehta@example.com  Ahmedabad          TV
# 7    Reena Shah   31    reena.shah@example.com     Jaipur     Speaker
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad      Router
#
#                                               Review  Rating  Price
# 1  This laptop has a great performance and batter...       9  56425
# 2    The tablet is lightweight and ideal for travel.       7  59622
# 4          The headphones have superb sound quality.       9  33271
# 6  The TV has a stunning display and vibrant colors.      10  22839
# 7  The speaker is portable and delivers powerful ...       7  52369
# 9  The router provides excellent internet speed a...       9  90812

# %%
dj.loc[(dj['Age'] >= 20) & (dj['Age'] <= 40), 'City']
# Out:
# 0       Mumbai
# 1        Delhi
# 3         Pune
# 4      Chennai
# 5        Surat
# 6    Ahmedabad
# 7       Jaipur
# 8      Kolkata
# 9    Hyderabad
# Name: City, dtype: object

# %%
dj.loc[dj['City'] == 'Mumbai']
# Out:
#          Name  Age                   Email    City     Product  \
# 0  Ravi Kumar   26  ravi.kumar@example.com  Mumbai  Smartphone
#
#                                               Review  Rating  Price
# 0  The smartphone is very user-friendly and durable.       8  94305

# %%
dj.loc[(dj['Age'] > 25) & (dj['City'] == 'Kolkata')]
# Out:
#            Name  Age                     Email     City         Product  \
# 8  Aditya Joshi   27  aditya.joshi@example.com  Kolkata  Gaming Console
#
#                                               Review  Rating  Price
# 8  The gaming console is fast and has a great gam...      10  24608

# %%
dj['City'].replace('Kolkata','KK')
# Out:
# 0       Mumbai
# 1        Delhi
# 2    Bangalore
# 3         Pune
# 4      Chennai
# 5        Surat
# 6    Ahmedabad
# 7       Jaipur
# 8           KK
# 9    Hyderabad
# Name: City, dtype: object

# %%
dj['Price'].replace(24608,np.nan)
# Out:
# 0    94305.0
# 1    56425.0
# 2    59622.0
# 3    67028.0
# 4    33271.0
# 5    43426.0
# 6    22839.0
# 7    52369.0
# 8        NaN
# 9    90812.0
# Name: Price, dtype: float64

# %%
dj.replace(26,50)
# Out:
#            Name  Age                     Email       City         Product  \
# 0    Ravi Kumar   50    ravi.kumar@example.com     Mumbai      Smartphone
# 1  Aditi Sharma   32  aditi.sharma@example.com      Delhi          Laptop
# 2   Aryan Gupta   45   aryan.gupta@example.com  Bangalore          Tablet
# 3    Isha Patel   29    isha.patel@example.com       Pune      Smartwatch
# 4  Nikhil Singh   38  nikhil.singh@example.com    Chennai      Headphones
# 5   Pooja Verma   24   pooja.verma@example.com      Surat          Camera
# 6   Aarav Mehta   40   aarav.mehta@example.com  Ahmedabad              TV
# 7    Reena Shah   31    reena.shah@example.com     Jaipur         Speaker
# 8  Aditya Joshi   27  aditya.joshi@example.com    Kolkata  Gaming Console
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad          Router
#
#                                               Review  Rating  Price
# 0  The smartphone is very user-friendly and durable.       8  94305
# ...

# %%
dj['Age'] = dj['Age'].replace("NA", pd.NA)
mean_age = dj['Age'].astype(float).mean()
dj['Age'] = dj['Age'].fillna(mean_age)
dj
# Out:
#            Name  Age                     Email       City         Product  \
# 0    Ravi Kumar   26    ravi.kumar@example.com     Mumbai      Smartphone
# 1  Aditi Sharma   32  aditi.sharma@example.com      Delhi          Laptop
# 2   Aryan Gupta   45   aryan.gupta@example.com  Bangalore          Tablet
# 3    Isha Patel   29    isha.patel@example.com       Pune      Smartwatch
# 4  Nikhil Singh   38  nikhil.singh@example.com    Chennai      Headphones
# 5   Pooja Verma   24   pooja.verma@example.com      Surat          Camera
# 6   Aarav Mehta   40   aarav.mehta@example.com  Ahmedabad              TV
# 7    Reena Shah   31    reena.shah@example.com     Jaipur         Speaker
# 8  Aditya Joshi   27  aditya.joshi@example.com    Kolkata  Gaming Console
# 9   Suman Reddy   36   suman.reddy@example.com  Hyderabad          Router
#
#                                               Review  Rating  Price
# 0  The smartphone is very user-friendly and durable.       8  94305
# ...

# %%
dj.set_index(['Name'], inplace=True)
dj
# Out:
#               index  Age                     Email       City         Product  \
# Name
# Ravi Kumar        0   26    ravi.kumar@example.com     Mumbai      Smartphone
# Aditi Sharma      1   32  aditi.sharma@example.com      Delhi          Laptop
# Aryan Gupta       2   45   aryan.gupta@example.com  Bangalore          Tablet
# Isha Patel        3   29    isha.patel@example.com       Pune      Smartwatch
# Nikhil Singh      4   38  nikhil.singh@example.com    Chennai      Headphones
# Pooja Verma       5   24   pooja.verma@example.com      Surat          Camera
# Aarav Mehta       6   40   aarav.mehta@example.com  Ahmedabad              TV
# Reena Shah        7   31    reena.shah@example.com     Jaipur         Speaker
# Aditya Joshi      8   27  aditya.joshi@example.com    Kolkata  Gaming Console
# Suman Reddy       9   36   suman.reddy@example.com  Hyderabad          Router
#
#                                                          Review  Rating  Price
# Name
# ...

# %%
dj.reset_index(inplace=True)
dj
# Out:
#         City          Name  Age                     Email         Product  \
# 0     Mumbai    Ravi Kumar   26    ravi.kumar@example.com      Smartphone
# 1      Delhi  Aditi Sharma   32  aditi.sharma@example.com          Laptop
# 2  Bangalore   Aryan Gupta   45   aryan.gupta@example.com          Tablet
# 3       Pune    Isha Patel   29    isha.patel@example.com      Smartwatch
# 4    Chennai  Nikhil Singh   38  nikhil.singh@example.com      Headphones
# 5      Surat   Pooja Verma   24   pooja.verma@example.com          Camera
# 6  Ahmedabad   Aarav Mehta   40   aarav.mehta@example.com              TV
# 7     Jaipur    Reena Shah   31    reena.shah@example.com         Speaker
# 8    Kolkata  Aditya Joshi   27  aditya.joshi@example.com  Gaming Console
# 9  Hyderabad   Suman Reddy   36   suman.reddy@example.com          Router
#
#                                               Review  Rating
# 0  The smartphone is very user-friendly and durable.       8
# ...

# %%
dj.set_index(['Age','City'], inplace=True)
dj
# Out:
#                                   Email         Product  \
# Age City
# 26  Mumbai       ravi.kumar@example.com      Smartphone
# 32  Delhi      aditi.sharma@example.com          Laptop
# 45  Bangalore   aryan.gupta@example.com          Tablet
# 29  Pune         isha.patel@example.com      Smartwatch
# 38  Chennai    nikhil.singh@example.com      Headphones
# 24  Surat       pooja.verma@example.com          Camera
# 40  Ahmedabad   aarav.mehta@example.com              TV
# 31  Jaipur       reena.shah@example.com         Speaker
# 27  Kolkata    aditya.joshi@example.com  Gaming Console
# 36  Hyderabad   suman.reddy@example.com          Router
#
#                                                           Review  Rating  \
# Age City
# 26  Mumbai     The smartphone is very user-friendly and durable.       8
# 32  Delhi      This laptop has a great performance and batter...       9
# 45  Bangalore    The tablet is lightweight and ideal for travel.       7
# ...

# %%
dj.set_index('City', inplace=True)
dj
specific=dj.loc['Kolkata']
print(specific)
# Out:
# Name                                            Aditya Joshi
# Age                                                       27
# Email                               aditya.joshi@example.com
# Product                                       Gaming Console
# Review     The gaming console is fast and has a great gam...
# Rating                                                    10
# Name: Kolkata, dtype: object

# %%
dj.set_index('City', inplace=True)

index_type = type(dj.index)

is_unique = dj.index.is_unique

print("Index type:", index_type)
print("Is the index unique?", is_unique)
# Out:
# Index type: <class 'pandas.core.indexes.base.Index'>
# Is the index unique? True

# %%
dj.groupby(['City', 'Age']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...
